# %%
import csv
import os
from datetime import datetime

# %%
FILE_NAME = "expenses.csv"

# %%
def initialize_file():
    if not os.path.exists(FILE_NAME):
        with open(FILE_NAME, "w", newline="") as file:
            writer = csv.writer(file)
            writer.writerow(["Date", "Category", "Amount", "Note"])

    print("Expense file is ready.")

# %%
initialize_file()
# Out:
# Expense file is ready.

# %%
def add_expense():
    print("\n========== ADD EXPENSE ==========")
    date = input("Enter date (YYYY-MM-DD): ")

    try:
        datetime.strptime(date, "%Y-%m-%d")
    except ValueError:
        print("Invalid date format! Please use YYYY-MM-DD.")
        return

    categories = [
        "Food",
        "Transport",
        "Shopping",
        "Education",
        "Entertainment",
        "Bills",
        "Health",
        "Travel",
        "Other"
    ]

    print("\nAvailable Categories:")
    for i, category in enumerate(categories, start=1):
        print(f"{i}. {category}")

    try:
        category_choice = int(input("\nSelect category number: "))

        if category_choice < 1 or category_choice > len(categories):
            print("Invalid category choice!")
            return

        category = categories[category_choice - 1]

    except ValueError:
        print("Invalid input! Please enter a category number.")
        return
    try:
        amount = float(input("Enter amount: "))

        if amount <= 0:
            print("Amount must be greater than 0.")
            return

    except ValueError:
        print("Invalid amount! Please enter a valid number.")
        return

    note = input("Enter note (optional): ").strip()
    with open(FILE_NAME, "a", newline="") as file:
        writer = csv.writer(file)
        writer.writerow([date, category, amount, note])

    print("\nExpense added successfully!")
    print(f"Category : {category}")
    print(f"Amount   : ₹{amount:.2f}")

# %%
def category_summary():
    print("\n====== CATEGORY-WISE SUMMARY ======")

    try:
        with open(FILE_NAME, "r", newline="") as file:
            reader = csv.DictReader(file)

            expenses = list(reader)

            if not expenses:
                print("No expenses recorded yet.")
                return

            category_totals = {}

            for expense in expenses:
                category = expense["Category"]
                amount = float(expense["Amount"])

                if category in category_totals:
                    category_totals[category] += amount
                else:
                    category_totals[category] = amount

            print("-" * 40)
            print(f"{'Category':<25}{'Amount':>15}")
            print("-" * 40)

            for category, total in category_totals.items():
                print(f"{category:<25}₹{total:>13.2f}")

            print("-" * 40)

    except FileNotFoundError:
        print("Expense file not found.")

# %%
def category_summary():
    print("\n====== CATEGORY-WISE SUMMARY ======")

    try:
        with open(FILE_NAME, "r", newline="") as file:
            reader = csv.DictReader(file)

            expenses = list(reader)

            if not expenses:
                print("No expenses recorded yet.")
                return

            category_totals = {}

            for expense in expenses:
                category = expense["Category"]
                amount = float(expense["Amount"])

                if category in category_totals:
                    category_totals[category] += amount
                else:
                    category_totals[category] = amount

            print("-" * 40)
            print(f"{'Category':<25}{'Amount':>15}")
            print("-" * 40)

            for category, total in category_totals.items():
                print(f"{category:<25}₹{total:>13.2f}")

            print("-" * 40)

    except FileNotFoundError:
        print("Expense file not found.")

# %%
# Main menu

def main_menu():

    while True:

        print("\n======================================")
        print("       EXPENSE TRACKER APPLICATION")
        print("======================================")
        print("1. Add Expense")
        print("2. View All Expenses")
        print("3. Category-Wise Summary")
        print("4. Exit")
        print("======================================")

        choice = input("Enter your choice: ")

        if choice == "1":
            add_expense()

        elif choice == "2":
            view_expenses()

        elif choice == "3":
            category_summary()

        elif choice == "4":
            print("\nThank you for using Expense Tracker!")
            break

        else:
            print("\nInvalid choice! Please select a number from 1 to 4.")

# %%
initialize_file()
main_menu()
# Out:
# Expense file is ready.
#
# ======================================
#        EXPENSE TRACKER APPLICATION
# ======================================
# 1. Add Expense
# 2. View All Expenses
# 3. Category-Wise Summary
# 4. Exit
# ======================================
# Enter your choice: 1
#
# ========== ADD EXPENSE ==========
# Enter date (YYYY-MM-DD): 2026-08-08
#
# Available Categories:
# 1. Food
# 2. Transport
# 3. Shopping
# 4. Education
# 5. Entertainment
# 6. Bills
# 7. Health
# 8. Travel
# 9. Other
#
# Select category number: 8
# Enter amount: 40
# Enter note (optional): Bus Ticket
#
# Expense added successfully!
# Category : Travel
# Amount   : ₹40.00
#
# ======================================
#        EXPENSE TRACKER APPLICATION
# ======================================
# 1. Add Expense
# 2. View All Expenses
# 3. Category-Wise Summary
# 4. Exit
# ======================================
# Enter your choice: 1
#
# ========== ADD EXPENSE ==========
# Enter date (YYYY-MM-DD): 1
# Invalid date format! Please use YYYY-MM-DD.
#
# ======================================
#        EXPENSE TRACKER APPLICATION
# ======================================
# 1. Add Expense
# 2. View All Expenses
# 3. Category-Wise Summary
# 4. Exit
# ======================================
# Enter your choice: 1
#
# ========== ADD EXPENSE ==========
# Enter date (YYYY-MM-DD): 2026-08-08
#
# Available Categories:
# 1. Food
# 2. Transport
# 3. Shopping
# 4. Education
# 5. Entertainment
# 6. Bills
# 7. Health
# 8. Travel
# 9. Other
#
# Select category number: 1
# Enter amount: 80
# Enter note (optional): Lunch
#
# Expense added successfully!
# Category : Food
# Amount   : ₹80.00
#
# ======================================
#        EXPENSE TRACKER APPLICATION
# ======================================
# 1. Add Expense
# 2. View All Expenses
# 3. Category-Wise Summary
# 4. Exit
# ======================================
# Enter your choice: 1
#
# ========== ADD EXPENSE ==========
# Enter date (YYYY-MM-DD): 2026-08-08
#
# Available Categories:
# 1. Food
# 2. Transport
# 3. Shopping
# 4. Education
# 5. Entertainment
# 6. Bills
# 7. Health
# 8. Travel
# 9. Other
#
# Select category number: 4
# Enter amount: 200
# Enter note (optional): Stattionary Aamount
#
# Expense added successfully!
# Category : Education
# Amount   : ₹200.00
#
# ======================================
#        EXPENSE TRACKER APPLICATION
# ======================================
# 1. Add Expense
# 2. View All Expenses
# 3. Category-Wise Summary
# 4. Exit
# ======================================
# Enter your choice: 1
#
# ========== ADD EXPENSE ==========
# Enter date (YYYY-MM-DD): 2026-08-08
#
# Available Categories:
# 1. Food
# 2. Transport
# 3. Shopping
# 4. Education
# 5. Entertainment
# 6. Bills
# 7. Health
# 8. Travel
# 9. Other
#
# Select category number: 9
# Enter amount: 80
# Enter note (optional): Other Payment
#
# Expense added successfully!
# Category : Other
# Amount   : ₹80.00
#
# ======================================
#        EXPENSE TRACKER APPLICATION
# ======================================
# 1. Add Expense
# 2. View All Expenses
# 3. Category-Wise Summary
# 4. Exit
# ======================================
# Enter your choice: 2
#
# ========== ALL EXPENSES ==========
# ----------------------------------------------------------------------
# Date           Category            Amount         Note
# ----------------------------------------------------------------------
# 2026-08-08     1                   500.00         item 1
# 2026-08-08     Travel              40.00          Bus Ticket
# 2026-08-08     Food                80.00          Lunch
# 2026-08-08     Education           200.00         Stattionary Aamount
# 2026-08-08     Other               80.00          Other Payment
# ----------------------------------------------------------------------
# Total Amount Spent: ₹900.00
#
# ======================================
#        EXPENSE TRACKER APPLICATION
# ======================================
# 1. Add Expense
# 2. View All Expenses
# 3. Category-Wise Summary
# 4. Exit
# ======================================
# Enter your choice: 3
#
# ====== CATEGORY-WISE SUMMARY ======
# ----------------------------------------
# Category                          Amount
# ----------------------------------------
# 1                        ₹       500.00
# Travel                   ₹        40.00
# Food                     ₹        80.00
# Education                ₹       200.00
# Other                    ₹        80.00
# ----------------------------------------
#
# ======================================
#        EXPENSE TRACKER APPLICATION
# ======================================
# 1. Add Expense
# 2. View All Expenses
# 3. Category-Wise Summary
# 4. Exit
# ======================================
# Enter your choice: 4
#
# Thank you for using Expense Tracker!
